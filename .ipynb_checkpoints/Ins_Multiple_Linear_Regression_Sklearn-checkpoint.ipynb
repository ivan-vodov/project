# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
wages_file = "BLS_Data.csv"
wages_df = pd.read_csv(wages_file, encoding = "UTF-8")

# %%
wages_df.head()
# Out:
#   PRIM_STATE   AREA                           AREA_NAME OCC_CODE  \
# 0         CA  31080  Los Angeles-Long Beach-Anaheim, CA  11-0000
# 1         CA  31080  Los Angeles-Long Beach-Anaheim, CA  13-0000
# 2         CA  31080  Los Angeles-Long Beach-Anaheim, CA  15-0000
# 3         CA  31080  Los Angeles-Long Beach-Anaheim, CA  17-0000
# 4         CA  31080  Los Angeles-Long Beach-Anaheim, CA  19-0000
#
#                                         OCC_TITLE  TOT_EMP  JOBS_1000  H_MEAN  \
# 0                          Management Occupations  337,700     55.845   63.33
# 1   Business and Financial Operations Occupations  366,110     60.544   38.97
# 2           Computer and Mathematical Occupations  165,650     27.394   45.25
# 3        Architecture and Engineering Occupations  105,740     17.486   47.00
# 4  Life, Physical, and Social Science Occupations   46,270      7.652   37.65
#
#     A_MEAN A_PCT10 A_PCT25 A_MEDIAN  A_PCT75     Market size
# 0  131,740  49,970  74,330  114,010  164,920  38,501,177,000
# 1   81,070  39,490  53,520   72,380   97,510  26,499,041,800
# 2   94,110  45,130  62,900   90,180  121,110  14,938,317,000
# 3   97,770  50,670  67,330   91,790  123,780   9,705,874,600
# 4   78,310  35,450  49,030   73,250   99,960   3,389,277,500

# %%
prices_file = "Zillow_Sale_Prices.csv"
prices_df = pd.read_csv(prices_file)
prices_df.head()
# Out:
#    ZillowRegionID                          RegionName  SizeRank   2008-03  \
# 0          102001                       United States         0  188000.0
# 1          394913                        New York, NY         1       NaN
# 2          753899  Los Angeles-Long Beach-Anaheim, CA         2  474800.0
# 3          394463                         Chicago, IL         3  254200.0
# 4          394514               Dallas-Fort Worth, TX         4       NaN
#
#     2008-04   2008-05   2008-06   2008-07   2008-08   2008-09    ...     \
# 0  184700.0  180600.0  176900.0  174900.0  173800.0  172900.0    ...
# 1       NaN       NaN       NaN       NaN       NaN       NaN    ...
# 2  463400.0  447100.0  435600.0  422300.0  408000.0  393600.0    ...
# 3  251600.0  238600.0  227200.0  224200.0  221900.0  221500.0    ...
# 4       NaN       NaN       NaN       NaN       NaN       NaN    ...
#
#     2017-09   2017-10   2017-11   2017-12   2018-01   2018-02   2018-03  \
# 0  220900.0  223400.0  227400.0  229100.0  233100.0  237200.0  240700.0
# 1  375300.0  373200.0  380700.0  384200.0  386600.0  389500.0  393400.0
# 2  604900.0  605600.0  615600.0  618700.0  622500.0  628400.0  631500.0
# 3  216500.0  217500.0  219300.0  226700.0  228600.0  234500.0  240300.0
# 4  239700.0  243500.0  244500.0  244500.0  245200.0  249000.0  251400.0
#
#     2018-04   2018-05   2018-06
# 0  239800.0  235100.0  231700.0
# 1  401700.0  401800.0       NaN
# 2  632400.0  627900.0  628200.0
# 3  243800.0  240600.0  236100.0
# 4  250700.0  248800.0  246800.0
#
# [5 rows x 127 columns]

# %%
mapping_file = "BLS-Zillow-Mapping.csv"
mapping_df = pd.read_csv(mapping_file)
mapping_df.head()
# Out:
#   PRIM_STATE   AREA                                     AREA_NAME State  \
# 0         CA  31080            Los Angeles-Long Beach-Anaheim, CA    CA
# 1         CA  41860             San Francisco-Oakland-Hayward, CA    CA
# 2         DC  47900  Washington-Arlington-Alexandria, DC-VA-MD-WV    DC
# 3         FL  33100     Miami-Fort Lauderdale-West Palm Beach, FL    FL
# 4         IL  16980                  Chicago-Naperville-Elgin, IL    IL
#
#                                  Metro Area          City1       City2  \
# 0            Los Angeles-Long Beach-Anaheim    Los Angeles  Long Beach
# 1             San Francisco-Oakland-Hayward  San Francisco     Oakland
# 2  Washington-Arlington-Alexandria, DC-VA-M     Washington   Arlington
# 3                     Miami-Fort Lauderdale          Miami     #VALUE!
# 4                  Chicago-Naperville-Elgin        Chicago  Naperville
#
#                  City3  ZillowMetro  ZillowCity1  ZillowCity2  ZillowCity3  \
# 0              Anaheim       753899            0            0            0
# 1              Hayward            0       395057            0            0
# 2  Alexandria, DC-VA-M            0       395209            0            0
# 3              #VALUE!       394856            0            0            0
# 4                Elgin            0       394463            0            0
#
#    ZillowRegionID
# 0          753899
# 1          395057
# 2          395209
# 3          394856
# 4          394463

# %%
mapping_df=mapping_df.loc[:,['AREA','ZillowRegionID']]
mapping_df.head()
# Out:
#     AREA  ZillowRegionID
# 0  31080          753899
# 1  41860          395057
# 2  47900          395209
# 3  33100          394856
# 4  16980          394463

# %%
mapping_df.dtypes
# Out:
# AREA              int64
# ZillowRegionID    int64
# dtype: object

# %%
prices_df=prices_df.loc[:,['ZillowRegionID','RegionName','2017-01']].rename(columns={'2017-01':'SalePrice'})
prices_df.head()
# Out:
#    ZillowRegionID                          RegionName  SalePrice
# 0          102001                       United States   217600.0
# 1          394913                        New York, NY   371800.0
# 2          753899  Los Angeles-Long Beach-Anaheim, CA   572400.0
# 3          394463                         Chicago, IL   225000.0
# 4          394514               Dallas-Fort Worth, TX   221800.0

# %%
market_size_pivot_df=wages_df.pivot(index='AREA', columns='OCC_CODE', values='Market size').reset_index()
market_size_pivot_df.head()
# Out:
# OCC_CODE   AREA         11-0000         13-0000         15-0000  \
# 0         16980  35,362,924,800  17,472,112,500  12,176,740,800
# 1         19100  16,721,583,900  14,316,630,300  12,799,962,000
# 2         19820  10,489,704,400   7,422,179,000   5,588,703,600
# 3         31080  38,501,177,000  26,499,041,800  14,938,317,000
# 4         33100  11,028,073,200   8,750,612,100   3,982,757,000
#
# OCC_CODE        17-0000        19-0000        21-0000        23-0000  \
# 0         5,242,783,000  1,761,485,400  2,519,994,900  3,548,978,400
# 1         5,441,721,600    897,669,500  1,350,588,800  2,318,677,100
# 2         7,729,005,000    558,389,700  1,033,717,600  1,221,090,000
# 3         9,705,874,600  3,389,277,500  5,120,488,800  5,714,648,100
# 4         1,749,399,000    594,808,000  1,196,183,000  2,448,307,000
#
# OCC_CODE         25-0000         27-0000       ...               35-0000  \
# 0         14,317,255,000   2,911,827,600       ...         8,366,171,600
# 1         10,252,123,600   1,984,366,800       ...         6,562,602,900
# 2          3,862,764,900   1,382,384,200       ...         3,461,057,600
# 3         19,175,401,800  11,144,397,300       ...        13,715,390,400
# 4          5,713,260,000   1,582,915,200       ...         5,451,160,400
#
# OCC_CODE        37-0000        39-0000         41-0000         43-0000  \
# 0         3,684,326,800  3,192,837,600  13,070,925,000  25,113,782,800
# 1         2,218,408,400  1,930,716,000  11,233,892,400  22,068,954,400
# 2         1,293,039,000  1,299,348,000   5,454,340,800  10,002,885,200
# 3         4,443,309,400  8,707,833,300  17,715,896,000  36,579,347,200
# 4         2,187,662,800  1,567,764,000   9,148,332,000  14,901,390,000
#
# OCC_CODE      45-0000        47-0000        49-0000         51-0000  \
# 0          69,556,800  9,570,333,600  7,545,699,900  10,788,426,100
# 1          76,947,200  5,601,515,400  6,217,556,400   6,048,921,200
# 2          27,784,000  3,152,244,600  3,462,576,400   7,190,773,500
# 3         126,741,000  9,657,945,600  8,444,421,700  10,479,352,000
# 4          91,455,000  3,706,595,200  4,189,263,000   2,419,427,700
#
# OCC_CODE         53-0000
# 0         11,314,424,800
# 1                   None
# 2          3,947,520,600
# 3                   None
# 4                   None
#
# [5 rows x 23 columns]

# %%
market_size_data_df=market_size_pivot_df.merge(mapping_df,on='AREA',how='inner')
market_size_data_df.head()
# Out:
#     AREA         11-0000         13-0000         15-0000        17-0000  \
# 0  16980  35,362,924,800  17,472,112,500  12,176,740,800  5,242,783,000
# 1  19100  16,721,583,900  14,316,630,300  12,799,962,000  5,441,721,600
# 2  31080  38,501,177,000  26,499,041,800  14,938,317,000  9,705,874,600
# 3  33100  11,028,073,200   8,750,612,100   3,982,757,000  1,749,399,000
# 4  35620  71,328,735,000  49,032,186,000  28,759,511,500  8,199,309,800
#
#          19-0000        21-0000         23-0000         25-0000  \
# 0  1,761,485,400  2,519,994,900   3,548,978,400  14,317,255,000
# 1    897,669,500  1,350,588,800   2,318,677,100  10,252,123,600
# 2  3,389,277,500  5,120,488,800   5,714,648,100  19,175,401,800
# 3    594,808,000  1,196,183,000   2,448,307,000   5,713,260,000
# 4  5,186,566,800  8,095,000,000  12,137,161,400  40,008,668,700
#
#           27-0000      ...              37-0000        39-0000  \
# 0   2,911,827,600      ...        3,684,326,800  3,192,837,600
# 1   1,984,366,800      ...        2,218,408,400  1,930,716,000
# 2  11,144,397,300      ...        4,443,309,400  8,707,833,300
# 3   1,582,915,200      ...        2,187,662,800  1,567,764,000
# 4  12,840,847,200      ...        9,730,272,000  9,647,007,400
#
#           41-0000         43-0000      45-0000         47-0000  \
# 0  13,070,925,000  25,113,782,800   69,556,800   9,570,333,600
# 1  11,233,892,400  22,068,954,400   76,947,200   5,601,515,400
# 2  17,715,896,000  36,579,347,200  126,741,000   9,657,945,600
# 3   9,148,332,000  14,901,390,000   91,455,000   3,706,595,200
# 4  29,139,053,200  60,810,594,900  114,481,400  19,486,104,200
#
#           49-0000         51-0000         53-0000 ZillowRegionID
# 0   7,545,699,900  10,788,426,100  11,314,424,800         394463
# 1   6,217,556,400   6,048,921,200            None         394514
# 2   8,444,421,700  10,479,352,000            None         753899
# 3   4,189,263,000   2,419,427,700            None         394856
# 4  15,292,944,000   9,845,128,800  20,068,729,500         394913
#
# [5 rows x 24 columns]

# %%
market_size_data_df=market_size_data_df.merge(prices_df, on='ZillowRegionID',how='inner')

# %%
market_size_data_df.head()
# Out:
#     AREA         11-0000         13-0000         15-0000        17-0000  \
# 0  16980  35,362,924,800  17,472,112,500  12,176,740,800  5,242,783,000
# 1  19100  16,721,583,900  14,316,630,300  12,799,962,000  5,441,721,600
# 2  31080  38,501,177,000  26,499,041,800  14,938,317,000  9,705,874,600
# 3  33100  11,028,073,200   8,750,612,100   3,982,757,000  1,749,399,000
# 4  35620  71,328,735,000  49,032,186,000  28,759,511,500  8,199,309,800
#
#          19-0000        21-0000         23-0000         25-0000  \
# 0  1,761,485,400  2,519,994,900   3,548,978,400  14,317,255,000
# 1    897,669,500  1,350,588,800   2,318,677,100  10,252,123,600
# 2  3,389,277,500  5,120,488,800   5,714,648,100  19,175,401,800
# 3    594,808,000  1,196,183,000   2,448,307,000   5,713,260,000
# 4  5,186,566,800  8,095,000,000  12,137,161,400  40,008,668,700
#
#           27-0000    ...            41-0000         43-0000      45-0000  \
# 0   2,911,827,600    ...     13,070,925,000  25,113,782,800   69,556,800
# 1   1,984,366,800    ...     11,233,892,400  22,068,954,400   76,947,200
# 2  11,144,397,300    ...     17,715,896,000  36,579,347,200  126,741,000
# 3   1,582,915,200    ...      9,148,332,000  14,901,390,000   91,455,000
# 4  12,840,847,200    ...     29,139,053,200  60,810,594,900  114,481,400
#
#           47-0000         49-0000         51-0000         53-0000  \
# 0   9,570,333,600   7,545,699,900  10,788,426,100  11,314,424,800
# 1   5,601,515,400   6,217,556,400   6,048,921,200            None
# 2   9,657,945,600   8,444,421,700  10,479,352,000            None
# 3   3,706,595,200   4,189,263,000   2,419,427,700            None
# 4  19,486,104,200  15,292,944,000   9,845,128,800  20,068,729,500
#
#   ZillowRegionID                          RegionName SalePrice
# 0         394463                         Chicago, IL  225000.0
# 1         394514               Dallas-Fort Worth, TX  221800.0
# 2         753899  Los Angeles-Long Beach-Anaheim, CA  572400.0
# 3         394856           Miami-Fort Lauderdale, FL  230800.0
# 4         394913                        New York, NY  371800.0
#
# [5 rows x 26 columns]

# %%
from sklearn.datasets import make_regression

n_features = 3
X, y = make_regression(n_samples=30, n_features=n_features, 
                       n_informative=n_features, random_state=42, 
                       noise=0.5, bias=100.0)
print(X.shape)
# Out:
# (30, 3)

# %% [markdown]
# With 3 or more dimensions, it becomes harder to visualize the linear trends in our data

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(1, figsize=(5, 5))
axes = Axes3D(fig, elev=20, azim=45)
axes.scatter(X[:,0], X[:,1], X[:,2], c=y, cmap=plt.cm.spectral)
plt.show()

# %%
y
# Out:
# array([ -30.09970593,   59.79676852,  169.525505  ,  -46.41541667,
#         170.22545453,  -31.37691622,  -42.06125512,  -94.18658521,
#          77.44118985,   74.85845235,  244.30949544,  146.3464125 ,
#         173.95260222,  -48.70246812,  -35.74044762,  189.01981997,
#          77.67231907,   96.96373549,  -17.03234168,  153.78189524,
#         204.74192439,  168.54054512, -120.2346508 ,   20.41387506,
#          61.74032229,  186.10006444,  145.33196979,  142.21035403,
#          85.64380786,  176.56779377])

# %% [markdown]
# We can still visualize 3 features as a 3D plot, but what about n-dimensions? This becomes very difficult for the human brain to visualize.

# %% [markdown]
# We could pick just one feature from X to fit our model, but what we really want it to find a line that best fits the data in n-dimensional space. To achieve this, Linear Regression can be solved using the analytical approach called [Ordinary Least Squares](https://en.wikipedia.org/wiki/Ordinary_least_squares) or a computational approach [Gradient Descent](https://en.wikipedia.org/wiki/Gradient_descent) for estimating the parameters. Note that there are [tradeoffs](https://stats.stackexchange.com/questions/23128/solving-for-regression-parameters-in-closed-form-vs-gradient-descent) between using either approach. The Linear Regression model in Sklearn uses the Ordinary Least Squares method.

# %% [markdown]
# Luckily, we can just supply our n-dimensional features and sklearn will fit the model using all of our features.

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# Fitting our model with all of our features in X
model.fit(X, y)

score = model.score(X, y)
print(f"R2 Score: {score}")
# Out:
# R2 Score: 0.9999838079561165

# %% [markdown]
# ## Residuals

# %% [markdown]
# Because we can't easily plot our line in 3D space, we can use a residual plot to check our predictions.

# %% [markdown]
# Residuals are the difference between the true values of y and the predicted values of y.

# %%
predictions = model.predict(X)
# Plot Residuals
plt.scatter(predictions, predictions - y)
plt.hlines(y=0, xmin=predictions.min(), xmax=predictions.max())
plt.show()

# %% [markdown]
# We want our predictions to be close to zero on the y-axis in this plot.

# %% [markdown]
# ## Your Turn!
